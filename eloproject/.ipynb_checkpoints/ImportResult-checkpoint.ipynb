# %%
import requests
from bs4 import BeautifulSoup

url="https://cyclocross24.com/race/17330/"

page=requests.get(url)

soup=BeautifulSoup(page.text,'html')

title=soup.find(class_="main_title").text

date=soup.find(class_="rs_date").text.strip()
import re


patter=re.compile(r"(.*)-(.*)\((.*)\)")
matc = patter.search(title)
if matc:
    racename=matc.group(1).strip()
    racecategory = matc.group(2).strip()
    levelofrace = matc.group(3).strip()

L=[a.find(class_="res_position").text+" "+a.find(class_="rurl").text for a in soup.find_all(class_="r1_row")]
R=[]

pattern = re.compile(
    r"([0-9]+)\s\b([A-Z'À-Ÿ-]+(?:\s[A-Z'À-Ÿ-]+)*)\b\s+\b([A-Z'À-Ÿ][a-z'à-ÿ]+(?:[-\s][A-ZÀ-Ÿ][a-z'à-ÿ]+)*)\b"#\s+\b([A-Z'`À-Ÿ0-9()\s.-]+)\b"#\s+(\w+\s[0-4])"#"\s+([A-Z0-9-]{2,}|[A-Z]+)"
)

for i in L:
    match = pattern.search(i)
    if match:
        position=match.group(1)
        nom = match.group(2)
        prenom = match.group(3)
        R.append({'place':position,'prenom': prenom,'nom': nom, 'racecategory': racecategory, 'racename': racename, 'date':date})
import csv

with open('test.csv', 'w', newline='',encoding='utf-8') as file:
    writer = csv.writer(file)
    field = ["place","prenom","nom","racecategory","racename","date"]
    writer.writerow(field)

    for j in R:
        writer.writerow([j["place"],j["prenom"],j["nom"],j["racecategory"],j["racename"],j["date"]])
assert len(R)==(int(R[-1]['place']))        

R
# Out:
# [{'place': '1',
#   'prenom': 'Habib',
#   'nom': 'LLANA',
#   'racecategory': 'Men Junior',
#   'racename': 'Albanian National Championships Cyclocross Tirana 2025',
#   'date': '11 January 2025'},
#  {'place': '2',
#   'prenom': 'Markelian',
#   'nom': 'BEDULLA',
#   'racecategory': 'Men Junior',
#   'racename': 'Albanian National Championships Cyclocross Tirana 2025',
#   'date': '11 January 2025'},
#  {'place': '3',
#   'prenom': 'Leo',
#   'nom': 'PIKU',
#   'racecategory': 'Men Junior',
#   'racename': 'Albanian National Championships Cyclocross Tirana 2025',
#   'date': '11 January 2025'},
#  {'place': '4',
#   'prenom': 'Indrit',
#   'nom': 'HAMETI',
#   'racecategory': 'Men Junior',
#   'racename': 'Albanian National Championships Cyclocross Tirana 2025',
#   'date': '11 January 2025'},
#  {'place': '5',
#   'prenom': 'Bekim',
#   'nom': 'TAFILI',
#   'racecategory': 'Men Junior',
#   'racename': 'Albanian National Championships Cyclocross Tirana 2025',
#   'date': '11 January 2025'}]

# %%
R
# Out:
# [{'place': '1',
#   'prenom': 'Stefano',
#   'nom': 'VIEZZI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '2',
#   'prenom': 'Samuele',
#   'nom': 'SCAPPINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '4',
#   'prenom': 'Tommaso',
#   'nom': 'CAFUERI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '5',
#   'prenom': 'Simone',
#   'nom': 'VARI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '6',
#   'prenom': 'Lorenzo',
#   'nom': 'DE LONGHI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '7',
#   'prenom': 'Edoardo',
#   'nom': 'BOLZAN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '8',
#   'prenom': 'Alan',
#   'nom': 'ZANOLINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '9',
#   'prenom': 'Leonardo',
#   'nom': 'URSELLA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '10',
#   'prenom': 'Enrico',
#   'nom': 'BARAZZUOL',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '11',
#   'prenom': 'Tommaso',
#   'nom': 'FERRI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '12',
#   'prenom': 'Tommaso',
#   'nom': 'TABOTTA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '13',
#   'prenom': 'Edoardo',
#   'nom': 'BONAFINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '14',
#   'prenom': 'Giacomo',
#   'nom': 'GHIARONI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '15',
#   'prenom': 'Matteo',
#   'nom': 'VALENTINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '16',
#   'prenom': 'Matteo',
#   'nom': 'SPANIO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '17',
#   'prenom': 'Marco',
#   'nom': 'BRAMATI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '18',
#   'prenom': 'Riccardo',
#   'nom': 'ARICI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '19',
#   'prenom': 'Fabio',
#   'nom': 'DRUSIN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '20',
#   'prenom': 'Filippo',
#   'nom': 'PROIETTI CESARINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '21',
#   'prenom': 'Alessandro',
#   'nom': 'PICCIN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '22',
#   'prenom': 'Nicolo',
#   'nom': "D'ALESSANDRO",
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '23',
#   'prenom': 'Jader',
#   'nom': 'CONCARI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '24',
#   'prenom': 'Simone',
#   'nom': 'MASSARO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '25',
#   'prenom': 'Simone',
#   'nom': 'GIAMPAOLO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '26',
#   'prenom': 'Alessandro',
#   'nom': 'NANNINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '27',
#   'prenom': 'Giulio',
#   'nom': 'PICH',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '28',
#   'prenom': 'Alessandro',
#   'nom': 'BONALDA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '29',
#   'prenom': 'Andrea',
#   'nom': 'CARBONE',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '30',
#   'prenom': 'Edoardo',
#   'nom': 'DI LUIGI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '31',
#   'prenom': 'Flavio',
#   'nom': 'CAVINA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '32',
#   'prenom': 'Samuele',
#   'nom': 'MAZZUCCO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '33',
#   'prenom': 'Giacomo',
#   'nom': 'GHERI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '34',
#   'prenom': 'Giorgio',
#   'nom': 'LETIZIA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'}]

# %%
a={'place': '3',
  'prenom': "Ettore",
  'nom': "PRA'",
  'racecategory': 'Men U23',
  'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
  'date': '12 January 2025'}

# %%
R.append(a)

# %%
R
# Out:
# [{'place': '1',
#   'prenom': 'Stefano',
#   'nom': 'VIEZZI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '2',
#   'prenom': 'Samuele',
#   'nom': 'SCAPPINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '4',
#   'prenom': 'Tommaso',
#   'nom': 'CAFUERI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '5',
#   'prenom': 'Simone',
#   'nom': 'VARI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '6',
#   'prenom': 'Lorenzo',
#   'nom': 'DE LONGHI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '7',
#   'prenom': 'Edoardo',
#   'nom': 'BOLZAN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '8',
#   'prenom': 'Alan',
#   'nom': 'ZANOLINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '9',
#   'prenom': 'Leonardo',
#   'nom': 'URSELLA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '10',
#   'prenom': 'Enrico',
#   'nom': 'BARAZZUOL',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '11',
#   'prenom': 'Tommaso',
#   'nom': 'FERRI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '12',
#   'prenom': 'Tommaso',
#   'nom': 'TABOTTA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '13',
#   'prenom': 'Edoardo',
#   'nom': 'BONAFINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '14',
#   'prenom': 'Giacomo',
#   'nom': 'GHIARONI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '15',
#   'prenom': 'Matteo',
#   'nom': 'VALENTINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '16',
#   'prenom': 'Matteo',
#   'nom': 'SPANIO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '17',
#   'prenom': 'Marco',
#   'nom': 'BRAMATI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '18',
#   'prenom': 'Riccardo',
#   'nom': 'ARICI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '19',
#   'prenom': 'Fabio',
#   'nom': 'DRUSIN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '20',
#   'prenom': 'Filippo',
#   'nom': 'PROIETTI CESARINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '21',
#   'prenom': 'Alessandro',
#   'nom': 'PICCIN',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '22',
#   'prenom': 'Nicolo',
#   'nom': "D'ALESSANDRO",
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '23',
#   'prenom': 'Jader',
#   'nom': 'CONCARI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '24',
#   'prenom': 'Simone',
#   'nom': 'MASSARO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '25',
#   'prenom': 'Simone',
#   'nom': 'GIAMPAOLO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '26',
#   'prenom': 'Alessandro',
#   'nom': 'NANNINI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '27',
#   'prenom': 'Giulio',
#   'nom': 'PICH',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '28',
#   'prenom': 'Alessandro',
#   'nom': 'BONALDA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '29',
#   'prenom': 'Andrea',
#   'nom': 'CARBONE',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '30',
#   'prenom': 'Edoardo',
#   'nom': 'DI LUIGI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '31',
#   'prenom': 'Flavio',
#   'nom': 'CAVINA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '32',
#   'prenom': 'Samuele',
#   'nom': 'MAZZUCCO',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '33',
#   'prenom': 'Giacomo',
#   'nom': 'GHERI',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '34',
#   'prenom': 'Giorgio',
#   'nom': 'LETIZIA',
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'},
#  {'place': '3',
#   'prenom': 'Ettore',
#   'nom': "PRA'",
#   'racecategory': 'Men U23',
#   'racename': "Italian National Championships Cyclocross Fae' di Oderzo 2025",
#   'date': '12 January 2025'}]

# %%
import csv

with open('test.csv', 'w', newline='',encoding='utf-8') as file:
    writer = csv.writer(file)
    field = ["place","prenom","nom","racecategory","racename","date"]
    writer.writerow(field)

    for j in R:
        writer.writerow([j["place"],j["prenom"],j["nom"],j["racecategory"],j["racename"],j["date"]])
assert len(R)==(int(R[-2]['place']))

# %%
R[0]
# Out:
# {'place': '1',
#  'prenom': 'Mattia',
#  'nom': 'AGOSTINACCHIO',
#  'racecategory': 'Men Junior',
#  'racename': 'Turin International Cyclocross 2024',
#  'date': '10 November 2024'}

# %%
a={'place': '45',
 'prenom': 'Lorenzo',
 'nom': "VIGANO'",
 'racecategory': 'Men Junior',
 'racename': 'Turin International Cyclocross 2024',
 'date': '10 November 2024'}

# %%
R.append(a)

# %%
len(R)
# Out:
# 37

# %%
a={'place': '3',
 'prenom': 'Ettore',
 'nom': "PRA'",
 'racecategory': 'Men Elite',
 'racename': "Trofeo Citta' Di Firenze 2024",
 'date': '1 November 2024'}

# %%
R.append(a)

# %%
len(R)
# Out:
# 38

# %%
import csv

with open('test.csv', 'w', newline='',encoding='utf-8') as file:
    writer = csv.writer(file)
    field = ["place","prenom","nom","racecategory","racename","date"]
    writer.writerow(field)

    for j in R:
        writer.writerow([j["place"],j["prenom"],j["nom"],j["racecategory"],j["racename"],j["date"]])
